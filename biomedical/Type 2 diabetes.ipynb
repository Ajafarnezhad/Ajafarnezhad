# %%
import pandas as pd
import numpy as np
import torch
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
from torch.nn import Linear, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils.class_weight import compute_class_weight
from sklearn.neighbors import kneighbors_graph
import torch.nn.functional as F
from torch.optim import Adam

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 
           'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
data = pd.read_csv(url, header=None, names=columns)

# %%
columns_to_check = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for col in columns_to_check:
    data[col] = data[col].replace(0, np.nan)
    data[col].fillna(data[col].mean(), inplace=True)

scaler = StandardScaler()
X = scaler.fit_transform(data.drop(columns=['Outcome']))
y = data['Outcome'].values

# %%
X_tensor = torch.tensor(X, dtype=torch.float)
y_tensor = torch.tensor(y, dtype=torch.long)
k = 10
adjacency_matrix = kneighbors_graph(X, n_neighbors=k, mode='connectivity', include_self=True)
edge_index = torch.tensor(np.array(adjacency_matrix.nonzero()), dtype=torch.long)

graph_data = Data(x=X_tensor, edge_index=edge_index, y=y_tensor)

# %%
train_idx, test_idx = train_test_split(range(len(graph_data.y)), test_size=0.2, random_state=42, stratify=graph_data.y)
train_mask = torch.tensor(train_idx, dtype=torch.long)
test_mask = torch.tensor(test_idx, dtype=torch.long)
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y), y=y)
class_weights = torch.tensor(class_weights, dtype=torch.float)

# %%
class GNNModel(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(GNNModel, self).__init__()
        self.conv1 = GCNConv(input_dim, hidden_dim)
        self.conv2 = GCNConv(hidden_dim, hidden_dim)
        self.conv3 = GCNConv(hidden_dim, hidden_dim)  # لایه سوم
        self.fc = Linear(hidden_dim, output_dim)
        self.dropout = Dropout(0.5)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = self.dropout(x)
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        x = self.fc(x)
        return F.log_softmax(x, dim=1)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
graph_data = graph_data.to(device)

input_dim = X.shape[1]
hidden_dim = 64
output_dim = len(np.unique(y))

model = GNNModel(input_dim, hidden_dim, output_dim).to(device)
optimizer = Adam(model.parameters(), lr=0.005, weight_decay=5e-5)
criterion = torch.nn.NLLLoss(weight=class_weights.to(device))

# %%
def train():
    model.train()
    optimizer.zero_grad()
    out = model(graph_data)
    loss = criterion(out[train_mask], graph_data.y[train_mask])
    loss.backward()
    optimizer.step()
    return loss.item()
def test():
    model.eval()
    out = model(graph_data)
    pred = out.argmax(dim=1)
    correct = pred[test_mask].eq(graph_data.y[test_mask]).sum().item()
    acc = correct / test_mask.size(0)
    return acc

# %%
for epoch in range(300):  # افزایش تعداد epochs
    loss = train()
    acc = test()
    print(f"Epoch {epoch+1}, Loss: {loss:.4f}, Accuracy: {acc:.4f}")
# Out:
# Epoch 1, Loss: 0.7129, Accuracy: 0.6104
# Epoch 2, Loss: 0.6593, Accuracy: 0.5779
# Epoch 3, Loss: 0.6348, Accuracy: 0.5974
# Epoch 4, Loss: 0.6161, Accuracy: 0.6299
# Epoch 5, Loss: 0.5786, Accuracy: 0.6818
# Epoch 6, Loss: 0.5529, Accuracy: 0.6818
# Epoch 7, Loss: 0.5575, Accuracy: 0.6948
# Epoch 8, Loss: 0.5272, Accuracy: 0.6883
# Epoch 9, Loss: 0.5432, Accuracy: 0.6818
# Epoch 10, Loss: 0.5329, Accuracy: 0.6753
# Epoch 11, Loss: 0.5409, Accuracy: 0.6753
# Epoch 12, Loss: 0.5268, Accuracy: 0.6948
# Epoch 13, Loss: 0.5360, Accuracy: 0.7013
# Epoch 205, Loss: 0.3950, Accuracy: 0.6948
# Epoch 206, Loss: 0.4085, Accuracy: 0.7078
# Epoch 207, Loss: 0.3887, Accuracy: 0.7078
# Epoch 208, Loss: 0.3817, Accuracy: 0.7013
# Epoch 209, Loss: 0.3824, Accuracy: 0.7013
# Epoch 210, Loss: 0.3863, Accuracy: 0.7013
# Epoch 211, Loss: 0.3897, Accuracy: 0.6948
# Epoch 212, Loss: 0.3891, Accuracy: 0.7013
# Epoch 213, Loss: 0.3861, Accuracy: 0.7208
# Epoch 214, Loss: 0.3889, Accuracy: 0.7143
# Epoch 215, Loss: 0.3816, Accuracy: 0.7143
# Epoch 216, Loss: 0.3895, Accuracy: 0.7273
# Epoch 217, Loss: 0.3855, Accuracy: 0.7078
# Epoch 218, Loss: 0.3877, Accuracy: 0.6883
# Epoch 219, Loss: 0.3826, Accuracy: 0.6883
# Epoch 220, Loss: 0.3711, Accuracy: 0.7078
# Epoch 221, Loss: 0.3884, Accuracy: 0.7013
# Epoch 222, Loss: 0.3815, Accuracy: 0.7013
# Epoch 223, Loss: 0.3739, Accuracy: 0.7078
# Epoch 224, Loss: 0.3710, Accuracy: 0.7143
# Epoch 225, Loss: 0.3782, Accuracy: 0.7078
# Epoch 226, Loss: 0.3858, Accuracy: 0.7013
# Epoch 227, Loss: 0.4021, Accuracy: 0.7078
# Epoch 228, Loss: 0.3840, Accuracy: 0.7143
# Epoch 229, Loss: 0.3819, Accuracy: 0.7208
# Epoch 230, Loss: 0.3738, Accuracy: 0.7208
# Epoch 231, Loss: 0.3809, Accuracy: 0.7208
# Epoch 232, Loss: 0.3765, Accuracy: 0.7338
# Epoch 233, Loss: 0.3855, Accuracy: 0.7273
# Epoch 234, Loss: 0.3744, Accuracy: 0.7338
# Epoch 235, Loss: 0.3625, Accuracy: 0.7403
# Epoch 236, Loss: 0.3712, Accuracy: 0.7468
# Epoch 237, Loss: 0.3676, Accuracy: 0.7338
# Epoch 238, Loss: 0.3825, Accuracy: 0.7078
# Epoch 239, Loss: 0.3921, Accuracy: 0.6948
# Epoch 240, Loss: 0.3697, Accuracy: 0.7013
# Epoch 241, Loss: 0.3706, Accuracy: 0.7013
# Epoch 242, Loss: 0.3805, Accuracy: 0.7013
# Epoch 243, Loss: 0.3837, Accuracy: 0.7013
# Epoch 244, Loss: 0.3701, Accuracy: 0.6948
# Epoch 245, Loss: 0.3759, Accuracy: 0.6948
# Epoch 246, Loss: 0.3768, Accuracy: 0.6948
# Epoch 247, Loss: 0.4026, Accuracy: 0.6883
# Epoch 248, Loss: 0.3834, Accuracy: 0.7013
# Epoch 249, Loss: 0.3730, Accuracy: 0.7078
# Epoch 250, Loss: 0.3781, Accuracy: 0.7078
# Epoch 251, Loss: 0.3557, Accuracy: 0.7078
# Epoch 252, Loss: 0.3782, Accuracy: 0.7078
# Epoch 253, Loss: 0.3803, Accuracy: 0.7273
# Epoch 254, Loss: 0.3639, Accuracy: 0.7273
# Epoch 255, Loss: 0.3693, Accuracy: 0.7013
# Epoch 256, Loss: 0.3704, Accuracy: 0.7013
# Epoch 257, Loss: 0.3800, Accuracy: 0.7143
# Epoch 258, Loss: 0.3704, Accuracy: 0.7143
# Epoch 259, Loss: 0.3830, Accuracy: 0.7143
# Epoch 260, Loss: 0.3705, Accuracy: 0.7208
# Epoch 261, Loss: 0.3625, Accuracy: 0.7208
# Epoch 262, Loss: 0.3653, Accuracy: 0.7078
# Epoch 263, Loss: 0.3829, Accuracy: 0.6948
# Epoch 264, Loss: 0.3705, Accuracy: 0.6948
# Epoch 265, Loss: 0.3762, Accuracy: 0.7013
# Epoch 266, Loss: 0.3592, Accuracy: 0.7143
# Epoch 267, Loss: 0.3758, Accuracy: 0.7143
# Epoch 268, Loss: 0.3876, Accuracy: 0.7013
# Epoch 269, Loss: 0.3677, Accuracy: 0.6948
# Epoch 270, Loss: 0.3656, Accuracy: 0.6948
# Epoch 271, Loss: 0.3762, Accuracy: 0.7078
# Epoch 272, Loss: 0.3815, Accuracy: 0.7143
# Epoch 273, Loss: 0.3835, Accuracy: 0.7208
# Epoch 274, Loss: 0.3506, Accuracy: 0.7273
# Epoch 275, Loss: 0.3711, Accuracy: 0.6948
# Epoch 276, Loss: 0.3609, Accuracy: 0.7143
# Epoch 277, Loss: 0.3847, Accuracy: 0.7143
# Epoch 278, Loss: 0.3569, Accuracy: 0.7078
# Epoch 279, Loss: 0.3670, Accuracy: 0.7143
# Epoch 280, Loss: 0.3694, Accuracy: 0.7078
# Epoch 281, Loss: 0.3680, Accuracy: 0.7078
# Epoch 282, Loss: 0.3765, Accuracy: 0.7143
# Epoch 283, Loss: 0.3557, Accuracy: 0.7143
# Epoch 284, Loss: 0.3680, Accuracy: 0.7078
# Epoch 285, Loss: 0.3466, Accuracy: 0.7208
# Epoch 286, Loss: 0.3587, Accuracy: 0.7013
# Epoch 287, Loss: 0.3517, Accuracy: 0.7013
# Epoch 288, Loss: 0.3555, Accuracy: 0.7013
# Epoch 289, Loss: 0.3620, Accuracy: 0.7013
# Epoch 290, Loss: 0.3665, Accuracy: 0.7143
# Epoch 291, Loss: 0.3473, Accuracy: 0.7143
# Epoch 292, Loss: 0.3453, Accuracy: 0.7208
# Epoch 293, Loss: 0.3590, Accuracy: 0.7078
# Epoch 294, Loss: 0.3480, Accuracy: 0.7078
# Epoch 295, Loss: 0.3527, Accuracy: 0.6948
# Epoch 296, Loss: 0.3505, Accuracy: 0.6818
# Epoch 297, Loss: 0.3520, Accuracy: 0.6948
# Epoch 298, Loss: 0.3608, Accuracy: 0.7078
# Epoch 299, Loss: 0.3522, Accuracy: 0.7143
# Epoch 300, Loss: 0.3579, Accuracy: 0.7143
